# %% [markdown]
# # Data Analysis Notebook
#
# Generated automatically from the Streamlit app.

# %%
import pandas as pd
import numpy as np

# Load your data
# df = pd.read_csv('your_file.csv')

# Basic profiling
# print(df.shape)
# print(df.dtypes)
# print(df.isna().sum())
